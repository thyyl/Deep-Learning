# %% [markdown]
# Data loading

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8fc8322d-d7df-4c39-88b5-207b61960d20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fc8322d-d7df-4c39-88b5-207b61960d20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving D&O.csv to D&O.csv

# %% [markdown]
# Load libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import itertools
import random
import os
import io

# %%
df = pd.read_csv(io.BytesIO(uploaded['D&O.csv']), index_col='Date', parse_dates=['Date'])
df
# Out:
#              Open   High    Low  Close  Adj Close      Volume
# Date
# 2004-12-28  0.390  0.495  0.390   0.46   0.425383  77841700.0
# 2004-12-29  0.465  0.510  0.460   0.50   0.462373  19786600.0
# 2004-12-30  0.500  0.510  0.475   0.48   0.443878   6846700.0
# 2004-12-31  0.485  0.510  0.480   0.49   0.453125   8420300.0
# 2005-01-03  0.500  0.520  0.485   0.51   0.471620   7385000.0
# ...           ...    ...    ...    ...        ...         ...
# 2021-05-19  4.350  4.420  4.040   4.11   4.110000  12099800.0
# 2021-05-20  4.190  4.330  4.000   4.04   4.040000   9428200.0
# 2021-05-21  4.140  4.290  3.920   4.20   4.200000   9529800.0
# 2021-05-24  4.240  4.420  4.170   4.40   4.400000   9666000.0
# 2021-05-25  4.450  4.500  4.210   4.40   4.400000  12091700.0
#
# [4068 rows x 6 columns]

# %% [markdown]
# We choose High and Volume as two attributes to consider in our model and remove some null values.

# %%
df = df.drop(['Open', 'Low', 'Close', 'Adj Close'], axis=1)
df = df.dropna()

# %%
minMaxScaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = minMaxScaler.fit_transform(df)

# %% [markdown]
# ### LSTM

# %%
def CreateData(df, future, past, train_test_split_percentage, validation_split_percentage):
  feature = df.shape[1]
  x_data, y_data = [], []

  for i in range(past, len(df) - future + 1):
    x_data.append(df[i - past:i, 0:feature])
    y_data.append(df[i + future - 1:i + future, 0])

  split_training_test_starting_point = int(round(train_test_split_percentage * len(x_data)))
  split_train_validation_starting_point = int(round(split_training_test_starting_point * (1 - validation_split_percentage)))

  X_train = x_data[:split_train_validation_starting_point]
  y_train = y_data[:split_train_validation_starting_point]

  X_val = x_data[split_train_validation_starting_point:split_training_test_starting_point]
  y_val = y_data[split_train_validation_starting_point:split_training_test_starting_point]

  X_test = x_data[split_training_test_starting_point:]
  y_test = y_data[split_training_test_starting_point:]

  return np.array(X_train), np.array(X_test), np.array(X_val), np.array(y_train), np.array(y_test), np.array(y_val)

# %%
X_train, X_test, X_val, y_train, y_test, y_val = CreateData(df_scaled, future=1, past=25, train_test_split_percentage=0.8, validation_split_percentage = 0)

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (2994, 25, 2)
# (749, 25, 2)
# (2994, 1)
# (749, 1)

# %% [markdown]
# LSTM Training

# %%
regressor = Sequential()

regressor.add(LSTM(units=256, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=256, return_sequences=False))
regressor.add(Dropout(0.2))

regressor.add(Dense(units=1, activation='linear'))
regressor.compile(optimizer='adam', loss='mse')

early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=150)
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
history = regressor.fit(X_train, y_train, validation_split=0.3, epochs=500, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/500
#
500
# 33/33 [==============================] - 11s 325ms/step - loss: 1.5029e-05 - val_loss: 2.1066e-05
# Epoch 345/500
# 33/33 [==============================] - 11s 325ms/step - loss: 1.4000e-05 - val_loss: 2.2328e-05
# Epoch 346/500
# 33/33 [==============================] - 11s 325ms/step - loss: 1.3940e-05 - val_loss: 2.1291e-05
# Epoch 00346: early stopping

# %% [markdown]
# #### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

# %% [markdown]
# Tune the number of layers and neurons in each layer

# %%
def CreateModel(n_layers, n_nodes):
  model = Sequential()
  input_shape = (25, 2)

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False))

  model.add(Dense(units=1, activation='linear'))
  model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

  return model

# %%
n_layers = [3, 4, 5]
n_nodes = [128, 256]

model = KerasClassifier(build_fn=CreateModel, verbose=False)
param_grid = dict(n_layers=n_layers, n_nodes=n_nodes)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid.fit(X_train, y_train)

print(f'Best Score: {grid.best_score_}')
print(f'Best Parameters: {grid.best_params_}')
# Out:
# Best Score: 0.01670006662607193
# Best Parameters: {'n_layers': 3, 'n_nodes': 128}

# %% [markdown]
# Tune the optimization algorithm

# %%
def CreateModel(optimizer):
  model = Sequential()
  input_shape = (25, 2)
  n_layers = 3
  n_nodes = 128
  activation = 'tanh'
  final_activation = 'sigmoid'
  loss = 'huber'

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape, activation=activation))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False, activation=activation))

  model.add(Dense(units=1, activation=final_activation))
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

  return model

# %%
optimizer = ['Adam', 'Adadelta', 'Adamax', 'Nadam']

model = KerasClassifier(build_fn=CreateModel, batch_size=100, epochs=100, verbose=False)
param_grid = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid.fit(X_train, y_train)

print(f'Best Score: {grid.best_score_}')
print(f'Best Parameters: {grid.best_params_}')
# Out:
# Best Score: 0.01670006662607193
# Best Parameters: {'optimizer': 'Adam'}

# %% [markdown]
# Tune learning rate of optimization algorithm

# %%
from keras.optimizers import Adam

# %%
def CreateModel(learning_rate, beta_1, beta_2):
  model = Sequential()
  input_shape = (25, 2)
  n_layers = 3
  n_nodes = 128
  activation = 'tanh'
  final_activation = 'sigmoid'
  loss = 'huber'
  optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2)

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape, activation=activation))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False, activation=activation))

  model.add(Dense(units=1, activation=final_activation))
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

  return model

# %%
learning_rate = [0.001, 0.01]
beta_1 = [0.4, 0.6, 0.8]
beta_2 = [0.4, 0.6, 0.8]

model = KerasClassifier(build_fn=CreateModel, batch_size=100, epochs=60, verbose=False)
param_grid = dict(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid.fit(X_train, y_train)

print(f'Best Score: {grid.best_score_}')
print(f'Best Parameters: {grid.best_params_}')
# Out:
# Best Score: 0.01670006662607193
# Best Parameters: {'beta_1': 0.4, 'beta_2': 0.4, 'learning_rate': 0.001}

# %% [markdown]
# Tune network weight initialization

# %%
def CreateModel(kernel_initializer):
  model = Sequential()
  input_shape = (25, 2)
  n_layers = 3
  n_nodes = 128
  activation = 'tanh'
  final_activation = 'sigmoid'
  loss = 'huber'
  learning_rate = 0.001
  beta_1 = 0.4
  beta_2 = 0.4
  optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2)

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape, activation=activation, kernel_initializer=kernel_initializer))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False, activation=activation, kernel_initializer=kernel_initializer))

  model.add(Dense(units=1, activation=final_activation))
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

  return model

# %%
kernel_initializer = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']

model = KerasClassifier(build_fn=CreateModel, batch_size=100, epochs=60, verbose=False)
param_grid = dict(kernel_initializer=kernel_initializer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid.fit(X_train, y_train)

print(f'Best Score: {grid.best_score_}')
print(f'Best Parameters: {grid.best_params_}')
# Out:
# Best Score: 0.01670006662607193
# Best Parameters: {'kernel_initializer': 'uniform'}

# %% [markdown]
# Tune the dropout regularization

# %%
from keras.constraints import maxnorm

# %%
def CreateModel(dropout_rate):
  model = Sequential()
  input_shape = (25, 2)
  n_layers = 3
  n_nodes = 128
  activation = 'tanh'
  final_activation = 'linear'
  loss = 'huber'
  learning_rate = 0.001
  beta_1 = 0.4
  beta_2 = 0.4
  kernel_initializer = 'uniform'
  optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2)

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape, activation=activation, kernel_initializer=kernel_initializer))
      model.add(Dropout(dropout_rate))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False, activation=activation, kernel_initializer=kernel_initializer))
      model.add(Dropout(dropout_rate))

  model.add(Dense(units=1, activation=final_activation))
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

  return model

# %%
dropout_rate = [0.1, 0.2, 0.3]

model = KerasClassifier(build_fn=CreateModel, batch_size=100, epochs=60, verbose=False)
param_grid = dict(dropout_rate=dropout_rate)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid.fit(X_train, y_train)

print(f'Best Score: {grid.best_score_}')
print(f'Best Parameters: {grid.best_params_}')
# Out:
# Best Score: 0.01670006662607193
# Best Parameters: {'dropout_rate': 0.1}

# %% [markdown]
# Early stopping and callbacks

# %%
def CreateModel():
  model = Sequential()
  input_shape = (25, 2)
  n_layers = 3
  n_nodes = 128
  activation = 'tanh'
  final_activation = 'linear'
  loss = 'huber'
  learning_rate = 0.001
  beta_1 = 0.4
  beta_2 = 0.4
  kernel_initializer = 'uniform'
  dropout_rate = 0.1
  optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2)

  for i in range(1, n_layers):
    if i == 1:
      model.add(LSTM(units=n_nodes, return_sequences=True, input_shape=input_shape, activation=activation, kernel_initializer=kernel_initializer))
      model.add(Dropout(dropout_rate))
    else:
      model.add(LSTM(units=n_nodes, return_sequences=False, activation=activation, kernel_initializer=kernel_initializer))
      model.add(Dropout(dropout_rate))

  model.add(Dense(units=1, activation=final_activation))
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

  return model

# %%
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=150)
file_path = 'best_model.h5'
model_checkpoint = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
model = CreateModel()
model.fit(X_train, y_train, validation_split=0.3, epochs=500, batch_size=50, callbacks=[early_stopping, model_checkpoint], verbose=0)
# Out:
# Epoch 00001: val_loss improved from inf to 0.00004, saving model to best_model.h5
#
# Epoch 00002: val_loss did not improve from 0.00004
#
# Epoch 00003: val_loss did not improve from 0.00004
#
# Epoch 00004: val_loss did not improve from 0.00004
#
# Epoch 00005: val_loss did not improve from 0.00004
#
# Epoch 00006: val_loss did not improve from 0.00004
#
# Epoch 00007: val_loss improved from 0.00004 to 0.00004, saving model to best_model.h5
#
# Epoch 00008: val_loss did not improve from 0.00004
#
# Epoch 00009: val_loss did not improve from 0.00004
#
# Epoch 00010: val_loss did not improve from 0.00004
#
# Epoch 00011: val_loss did not improve from 0.00004
#
# Epoch 00012: val_loss did not improve from 0.00004
#
# Epoch 00013: val_loss did not improve from 0.00004
#
# Epoch 00014: val_loss improved from 0.00004 to 0.00002, saving model to best_model.h5
#
# Epoch 00015: val_loss did not improve from 0.00002
#
# Epoch 00016: val_loss did not improve from 0.00002
#
# Epoch 00017: val_loss did not improve from 0.00002
#
# Epoch 00018: val_loss did not improve from 0.00002
#
# Epoch 00019: val_loss did not improve from 0.00002
#
# Epoch 00020: val_loss did not improve from 0.00002
#
# Epoch 00021: val_loss did not improve from 0.00002
#
# Epoch 00022: val_loss did not improve from 0.00002
#
# Epoch 00023: val_loss did not improve from 0.00002
#
# Epoch 00024: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00025: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00026: val_loss did not improve from 0.00002
#
# Epoch 00027: val_loss did not improve from 0.00002
#
# Epoch 00028: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00029: val_loss did not improve from 0.00002
#
# Epoch 00030: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00031: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00032: val_loss improved from 0.00002 to 0.00002, saving model to best_model.h5
#
# Epoch 00033: val_loss did not improve from 0.00002
#
# Epoch 00034: val_loss improved from 0.00002 to 0.00001, saving model to best_model.h5
#
# Epoch 00035: val_loss did not improve from 0.00001
#
# Epoch 00036: val_loss did not improve from 0.00001
#
# Epoch 00037: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00038: val_loss did not improve from 0.00001
#
# Epoch 00039: val_loss did not improve from 0.00001
#
# Epoch 00040: val_loss did not improve from 0.00001
#
# Epoch 00041: val_loss did not improve from 0.00001
#
# Epoch 00042: val_loss did not improve from 0.00001
#
# Epoch 00043: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00044: val_loss did not improve from 0.00001
#
# Epoch 00045: val_loss did not improve from 0.00001
#
# Epoch 00046: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00047: val_loss did not improve from 0.00001
#
# Epoch 00048: val_loss did not improve from 0.00001
#
# Epoch 00049: val_loss did not improve from 0.00001
#
# Epoch 00050: val_loss did not improve from 0.00001
#
# Epoch 00051: val_loss did not improve from 0.00001
#
# Epoch 00052: val_loss did not improve from 0.00001
#
# Epoch 00053: val_loss did not improve from 0.00001
#
# Epoch 00054: val_loss did not improve from 0.00001
#
# Epoch 00055: val_loss did not improve from 0.00001
#
# Epoch 00056: val_loss did not improve from 0.00001
#
# Epoch 00057: val_loss did not improve from 0.00001
#
# Epoch 00058: val_loss did not improve from 0.00001
#
# Epoch 00059: val_loss did not improve from 0.00001
#
# Epoch 00060: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00061: val_loss did not improve from 0.00001
#
# Epoch 00062: val_loss did not improve from 0.00001
#
# Epoch 00063: val_loss did not improve from 0.00001
#
# Epoch 00064: val_loss did not improve from 0.00001
#
# Epoch 00065: val_loss did not improve from 0.00001
#
# Epoch 00066: val_loss did not improve from 0.00001
#
# Epoch 00067: val_loss did not improve from 0.00001
#
# Epoch 00068: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00069: val_loss did not improve from 0.00001
#
# Epoch 00070: val_loss did not improve from 0.00001
#
# Epoch 00071: val_loss did not improve from 0.00001
#
# Epoch 00072: val_loss did not improve from 0.00001
#
# Epoch 00073: val_loss did not improve from 0.00001
#
# Epoch 00074: val_loss did not improve from 0.00001
#
# Epoch 00075: val_loss did not improve from 0.00001
#
# Epoch 00076: val_loss did not improve from 0.00001
#
# Epoch 00077: val_loss did not improve from 0.00001
#
# Epoch 00078: val_loss did not improve from 0.00001
#
# Epoch 00079: val_loss did not improve from 0.00001
#
# Epoch 00080: val_loss did not improve from 0.00001
#
# Epoch 00081: val_loss did not improve from 0.00001
#
# Epoch 00082: val_loss did not improve from 0.00001
#
# Epoch 00083: val_loss did not improve from 0.00001
#
# Epoch 00084: val_loss did not improve from 0.00001
#
# Epoch 00085: val_loss did not improve from 0.00001
#
# Epoch 00086: val_loss did not improve from 0.00001
#
# Epoch 00087: val_loss did not improve from 0.00001
#
# Epoch 00088: val_loss did not improve from 0.00001
#
# Epoch 00089: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00090: val_loss did not improve from 0.00001
#
# Epoch 00091: val_loss did not improve from 0.00001
#
# Epoch 00092: val_loss did not improve from 0.00001
#
# Epoch 00093: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00094: val_loss did not improve from 0.00001
#
# Epoch 00095: val_loss did not improve from 0.00001
#
# Epoch 00096: val_loss did not improve from 0.00001
#
# Epoch 00097: val_loss did not improve from 0.00001
#
# Epoch 00098: val_loss did not improve from 0.00001
#
# Epoch 00099: val_loss did not improve from 0.00001
#
# Epoch 00100: val_loss did not improve from 0.00001
#
# Epoch 00101: val_loss did not improve from 0.00001
#
# Epoch 00102: val_loss did not improve from 0.00001
#
# Epoch 00103: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00104: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00105: val_loss did not improve from 0.00001
#
# Epoch 00106: val_loss did not improve from 0.00001
#
# Epoch 00107: val_loss did not improve from 0.00001
#
# Epoch 00108: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00109: val_loss did not improve from 0.00001
#
# Epoch 00110: val_loss improved from 0.00001 to 0.00001, saving model to best_model.h5
#
# Epoch 00111: val_loss did not improve from 0.00001
#
# Epoch 00112: val_loss did not improve from 0.00001
#
# Epoch 00113: val_loss did not improve from 0.00001
#
# Epoch 00114: val_loss did not improve from 0.00001
#
# Epoch 00115: val_loss did not improve from 0.00001
#
# Epoch 00116: val_loss did not improve from 0.00001
#
# Epoch 00117: val_loss did not improve from 0.00001
#
# Epoch 00118: val_loss did not improve from 0.00001
#
# Epoch 00119: val_loss did not improve from 0.00001
#
# Epoch 00120: val_loss did not improve from 0.00001
#
# Epoch 00121: val_loss did not improve from 0.00001
#
# Epoch 00122: val_loss did not improve from 0.00001
#
# Epoch 00123: val_loss did not improve from 0.00001
#
# Epoch 00124: val_loss did not improve from 0.00001
#
# Epoch 00125: val_loss did not improve from 0.00001
#
# Epoch 00126: val_loss did not improve from 0.00001
#
# Epoch 00127: val_loss did not improve from 0.00001
#
# Epoch 00128: val_loss did not improve from 0.00001
#
# Epoch 00129: val_loss did not improve from 0.00001
#
# Epoch 00130: val_loss did not improve from 0.00001
#
# Epoch 00131: val_loss did not improve from 0.00001
#
# Epoch 00132: val_loss did not improve from 0.00001
#
# Epoch 00133: val_loss did not improve from 0.00001
#
# Epoch 00134: val_loss did not improve from 0.00001
#
# Epoch 00135: val_loss did not improve from 0.00001
#
# Epoch 00136: val_loss did not improve from 0.00001
#
# Epoch 00137: val_loss did not improve from 0.00001
#
# Epoch 00138: val_loss did not improve from 0.00001
#
# Epoch 00139: val_loss did not improve from 0.00001
#
# Epoch 00140: val_loss did not improve from 0.00001
#
# Epoch 00141: val_loss did not improve from 0.00001
#
# Epoch 00142: val_loss did not improve from 0.00001
#
# Epoch 00143: val_loss did not improve from 0.00001
#
# Epoch 00144: val_loss did not improve from 0.00001
#
# Epoch 00145: val_loss did not improve from 0.00001
#
# Epoch 00146: val_loss did not improve from 0.00001
#
# Epoch 00147: val_loss did not improve from 0.00001
#
# Epoch 00148: val_loss did not improve from 0.00001
#
# Epoch 00149: val_loss did not improve from 0.00001
#
# Epoch 00150: val_loss did not improve from 0.00001
#
# Epoch 00151: val_loss did not improve from 0.00001
#
# Epoch 00152: val_loss did not improve from 0.00001
#
# Epoch 00153: val_loss did not improve from 0.00001
#
# Epoch 00154: val_loss did not improve from 0.00001
#
# Epoch 00155: val_loss did not improve from 0.00001
#
# Epoch 00156: val_loss did not improve from 0.00001
#
# Epoch 00157: val_loss did not improve from 0.00001
#
# Epoch 00158: val_loss did not improve from 0.00001
#
# Epoch 00159: val_loss did not improve from 0.00001
#
# Epoch 00160: val_loss did not improve from 0.00001
#
# Epoch 00161: val_loss did not improve from 0.00001
#
# Epoch 00162: val_loss did not improve from 0.00001
#
# Epoch 00163: val_loss did not improve from 0.00001
#
# Epoch 00164: val_loss did not improve from 0.00001
#
# Epoch 00165: val_loss did not improve from 0.00001
#
# Epoch 00166: val_loss did not improve from 0.00001
#
# Epoch 00167: val_loss did not improve from 0.00001
#
# Epoch 00168: val_loss did not improve from 0.00001
#
# Epoch 00169: val_loss did not improve from 0.00001
#
# Epoch 00170: val_loss did not improve from 0.00001
#
# Epoch 00171: val_loss did not improve from 0.00001
#
# Epoch 00172: val_loss did not improve from 0.00001
#
# Epoch 00173: val_loss did not improve from 0.00001
#
# Epoch 00174: val_loss did not improve from 0.00001
#
# Epoch 00175: val_loss did not improve from 0.00001
#
# Epoch 00176: val_loss did not improve from 0.00001
#
# Epoch 00177: val_loss did not improve from 0.00001
#
# Epoch 00178: val_loss did not improve from 0.00001
#
# Epoch 00179: val_loss did not improve from 0.00001
#
# Epoch 00180: val_loss did not improve from 0.00001
#
# Epoch 00181: val_loss did not improve from 0.00001
#
# Epoch 00182: val_loss did not improve from 0.00001
#
# Epoch 00183: val_loss did not improve from 0.00001
#
# Epoch 00184: val_loss did not improve from 0.00001
#
# Epoch 00185: val_loss did not improve from 0.00001
#
# Epoch 00186: val_loss did not improve from 0.00001
#
# Epoch 00187: val_loss did not improve from 0.00001
#
# Epoch 00188: val_loss did not improve from 0.00001
#
# Epoch 00189: val_loss did not improve from 0.00001
#
# Epoch 00190: val_loss did not improve from 0.00001
#
# Epoch 00191: val_loss did not improve from 0.00001
#
# Epoch 00192: val_loss did not improve from 0.00001
#
# Epoch 00193: val_loss did not improve from 0.00001
#
# Epoch 00194: val_loss did not improve from 0.00001
#
# Epoch 00195: val_loss did not improve from 0.00001
#
# Epoch 00196: val_loss did not improve from 0.00001
#
# Epoch 00197: val_loss did not improve from 0.00001
#
# Epoch 00198: val_loss did not improve from 0.00001
#
# Epoch 00199: val_loss did not improve from 0.00001
#
# Epoch 00200: val_loss did not improve from 0.00001
#
# Epoch 00201: val_loss did not improve from 0.00001
#
# Epoch 00202: val_loss did not improve from 0.00001
#
# Epoch 00203: val_loss did not improve from 0.00001
#
# Epoch 00204: val_loss did not improve from 0.00001
#
# Epoch 00205: val_loss did not improve from 0.00001
#
# Epoch 00206: val_loss did not improve from 0.00001
#
# Epoch 00207: val_loss did not improve from 0.00001
#
# Epoch 00208: val_loss did not improve from 0.00001
#
# Epoch 00209: val_loss did not improve from 0.00001
#
# Epoch 00210: val_loss did not improve from 0.00001
#
# Epoch 00211: val_loss did not improve from 0.00001
#
# Epoch 00212: val_loss did not improve from 0.00001
#
# Epoch 00213: val_loss did not improve from 0.00001
#
# Epoch 00214: val_loss did not improve from 0.00001
#
# Epoch 00215: val_loss did not improve from 0.00001
#
# Epoch 00216: val_loss did not improve from 0.00001
#
# Epoch 00217: val_loss did not improve from 0.00001
#
# Epoch 00218: val_loss did not improve from 0.00001
#
# Epoch 00219: val_loss did not improve from 0.00001
#
# Epoch 00220: val_loss did not improve from 0.00001
#
# Epoch 00221: val_loss did not improve from 0.00001
#
# Epoch 00222: val_loss did not improve from 0.00001
#
# Epoch 00223: val_loss did not improve from 0.00001
#
# Epoch 00224: val_loss did not improve from 0.00001
#
# Epoch 00225: val_loss did not improve from 0.00001
#
# Epoch 00226: val_loss did not improve from 0.00001
#
# Epoch 00227: val_loss did not improve from 0.00001
#
# Epoch 00228: val_loss did not improve from 0.00001
#
# Epoch 00229: val_loss did not improve from 0.00001
#
# Epoch 00230: val_loss did not improve from 0.00001
#
# Epoch 00231: val_loss did not improve from 0.00001
#
# Epoch 00232: val_loss did not improve from 0.00001
#
# Epoch 00233: val_loss did not improve from 0.00001
#
# Epoch 00234: val_loss did not improve from 0.00001
#
# Epoch 00235: val_loss did not improve from 0.00001
#
# Epoch 00236: val_loss did not improve from 0.00001
#
# Epoch 00237: val_loss did not improve from 0.00001
#
# Epoch 00238: val_loss did not improve from 0.00001
#
# Epoch 00239: val_loss did not improve from 0.00001
#
# Epoch 00240: val_loss did not improve from 0.00001
#
# Epoch 00241: val_loss did not improve from 0.00001
#
# Epoch 00242: val_loss did not improve from 0.00001
#
# Epoch 00243: val_loss did not improve from 0.00001
#
# Epoch 00244: val_loss did not improve from 0.00001
#
# Epoch 00245: val_loss did not improve from 0.00001
#
# Epoch 00246: val_loss did not improve from 0.00001
#
# Epoch 00247: val_loss did not improve from 0.00001
#
# Epoch 00248: val_loss did not improve from 0.00001
#
# Epoch 00249: val_loss did not improve from 0.00001
#
# Epoch 00250: val_loss did not improve from 0.00001
#
# Epoch 00251: val_loss did not improve from 0.00001
#
# Epoch 00252: val_loss did not improve from 0.00001
#
# Epoch 00253: val_loss did not improve from 0.00001
#
# Epoch 00254: val_loss did not improve from 0.00001
#
# Epoch 00255: val_loss did not improve from 0.00001
#
# Epoch 00256: val_loss did not improve from 0.00001
#
# Epoch 00257: val_loss did not improve from 0.00001
#
# Epoch 00258: val_loss did not improve from 0.00001
#
# Epoch 00259: val_loss did not improve from 0.00001
#
# Epoch 00260: val_loss did not improve from 0.00001
# Epoch 00260: early stopping

# %%
model.evaluate(X_test, y_test)
# Out:
# 24/24 [==============================] - 0s 18ms/step - loss: 3.9134e-04 - accuracy: 0.0013
# [0.0003913354885298759, 0.0013351135421544313]

# %%
y_pred = model.predict(X_test)

plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_test, color='red', label = 'Real High Price')
plt.plot(y_pred, color='green', label = 'Predicted High Price')
plt.legend(loc='best')

# %%
saved_model = load_model('best_model.h5')

# %%
saved_model.evaluate(X_test, y_test)
# Out:
# 24/24 [==============================] - 1s 18ms/step - loss: 1.1520e-04 - accuracy: 0.0013
# [0.00011520356929395348, 0.0013351135421544313]

# %%
y_pred = saved_model.predict(X_test)

plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_test, color='red', label = 'Real High Price')
plt.plot(y_pred, color='green', label = 'Predicted High Price')
plt.legend(loc='best')
